# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("DataSet.csv")

# %%
df.head(1000000)
# Out:
#                             Location_Desc Police_Beat Street_Type  RecordID  \
# 0                                     NaN       14D40          RD         1
# 1                                     NaN        7C20         NaN         2
# 2                                     NaN       13D40        PKWY         3
# 3                                     NaN       18F40          RD         4
# 4                    RESTAURANT/CAFETERIA       24C60        PKWY         5
# 5           MISC. BUSINESS (NON-SPECIFIC)       18F60        BLVD         6
# 6                                     NaN       12D20         FWY         7
# 7                       OTHER PARKING LOT        3B10         NaN         8
# 8                   APARTMENT PARKING LOT        5F10          DR         9
# 9                         OFFICE BUILDING        1A20         NaN        10
# 10                          OTHER/UNKNOWN       11H10         NaN        11
# ...

# %%
df.groupby("Street_Name").count().sort_values("Num_Offenses", ascending = False).Num_Offenses.head(30).plot.bar()

# %%
df["Street_Name"].value_counts().head(100)
# Out:
# WESTHEIMER           29602
# GULF                 15444
# GESSNER              15433
# NORTH                13584
# RICHMOND             13524
# KATY                 10958
# SOUTHWEST            10816
# MAIN                 10043
# BISSONNET            10036
# NORTHWEST             9730
# BELLAIRE              9415
# BELLFORT              8424
# FM 1960               8111
# BEECHNUT              7807
# GREENS                7723
# FONDREN               7672
# POST OAK              7301
# TIDWELL               7001
# LITTLE YORK           6884
# BROADWAY              6754
# WEST SAM HOUSTON      6364
# EAST                  6291
# SHEPHERD              6065
# AIRLINE               5622
# KIRBY                 5280
# SAM HOUSTON           5269
# HILLCROFT             4911
# FANNIN                4858
# LOOP                  4677
# WILCREST              4644
#                      ...
# HOLLISTER             2425
# CORPORATE             2408
# OLD SPANISH           2388
# ...

# %%
df.groupby("Police_Beat").count().sort_values("Num_Offenses", ascending = False).Num_Offenses.head(30).plot.bar()

# %%
df["Police_Beat"].value_counts()
# Out:
# 19G10    23473
# 12D10    23128
# 1A20     22591
# 6B60     22027
# 13D20    20751
# 3B10     20083
# 18F20    19140
# 17E10    19100
# 5F30     18068
# 18F30    17933
# 18F40    17841
# 15E40    17813
# 1A30     17800
# 14D20    17373
# 1A10     16926
# 20G30    16911
# 20G50    16891
# 17E40    16791
# 2A50     16345
# 1A50     16129
# 6B10     15784
# 18F50    15678
# 5F40     15174
# 7C20     15045
# 9C40     14663
# 6B30     14157
# 3B50     13894
# 2A30     13887
# 20G10    13758
# 19G40    13356
#          ...
# 11H50     2951
# 24C10     2809
# 24C50     2681
# 24C30     2637
# 24C20     2611
# 1A40      2532
# 9C10      2483
# 12D50     2398
# 11H40     2274
# 18F10     2251
# 21I50     2106
# 21I10     1272
# 13D30     1131
# 24C40     1130
# 23J50     1011
# 24C60      746
# 21I30      587
# 21I60      430
# 21I20      316
# 21I70      171
# 21I40      108
# HCSO        68
# OOJ         41
# 23J40       28
# 23J30       13
# UH3P         6
# 23J20        3
# ...
