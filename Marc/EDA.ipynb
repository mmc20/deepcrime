# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("DataSet.csv")

# %%
df.head(30)
# Out:
#                         Location_Desc Police_Beat Street_Type  RecordID  \
# 0                                 NaN       14D40          RD         1
# 1                                 NaN        7C20         NaN         2
# 2                                 NaN       13D40        PKWY         3
# 3                                 NaN       18F40          RD         4
# 4                RESTAURANT/CAFETERIA       24C60        PKWY         5
# 5       MISC. BUSINESS (NON-SPECIFIC)       18F60        BLVD         6
# 6                                 NaN       12D20         FWY         7
# 7                   OTHER PARKING LOT        3B10         NaN         8
# 8               APARTMENT PARKING LOT        5F10          DR         9
# 9                     OFFICE BUILDING        1A20         NaN        10
# 10                      OTHER/UNKNOWN       11H10         NaN        11
# 11            RENTAL STORAGE FACILITY       19G20          ST        12
# ...

# %%
df.count()
# Out:
# Location_Desc      1058263
# Police_Beat        1090899
# Street_Type         832422
# RecordID           1094207
# Date_Reported      1094203
# Offense_Type       1094207
# Block_Range        1094050
# Street_Prefix       150422
# Street_Name        1094205
# Num_Offenses       1094207
# Srce_YYMM          1094207
# NGC                 242420
# Match_addr         1063260
# X                  1080683
# Y                  1080683
# GEOID10            1063260
# GEOID00            1063260
# Police_Division    1051759
# CTA_ID             1049989
# CTA_Name           1049989
# Geocoded           1094207
# Location_Code      1058200
# Hour               1094207
# dtype: int64

# %%
df.groupby("Location_Desc").count().sort_values("Num_Offenses", ascending = False).Num_Offenses.head(15).plot.bar()
