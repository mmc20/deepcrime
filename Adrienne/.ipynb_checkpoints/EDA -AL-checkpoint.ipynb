# %%
# it's best practice to have your imports up top so others can immediately know what to install
# if you import more modules, add them here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
plt.rcParams["figure.figsize"] = 10, 6
plt.rcParams["figure.dpi"] = 150

# %%
# reading from a CSV: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
# df = pd.read_csv("data/foo.csv")

# reading from a CSV without column names
# df = pd.read_csv("data/foo.csv", columns=["date", "company", "valuation"])

# %%
df = pd.read_csv("Documents/cs1/jupyter_notebooks_ML_2018-master/data/HPD_Crime.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-c4218460c405> in <module>()
# ----> 1 df = pd.read_csv("Documents/cs1/jupyter_notebooks_ML_2018-master/data/HPD_Crime.csv")
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas\_libs\parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas\_libs\parsers.c:8873)()
#
# FileNotFoundError: File b'Documents/cs1/jupyter_notebooks_ML_2018-master/data/HPD_Crime.csv' does not exist

# %%
df.head(50)
# Out:
#                         Location_Desc Police_Beat Street_Type  RecordID  \
# 0                                 NaN       14D40          RD         1
# 1                                 NaN        7C20         NaN         2
# 2                                 NaN       13D40        PKWY         3
# 3                                 NaN       18F40          RD         4
# 4                RESTAURANT/CAFETERIA       24C60        PKWY         5
# 5       MISC. BUSINESS (NON-SPECIFIC)       18F60        BLVD         6
# 6                                 NaN       12D20         FWY         7
# 7                   OTHER PARKING LOT        3B10         NaN         8
# 8               APARTMENT PARKING LOT        5F10          DR         9
# 9                     OFFICE BUILDING        1A20         NaN        10
# 10                      OTHER/UNKNOWN       11H10         NaN        11
# 11            RENTAL STORAGE FACILITY       19G20          ST        12
# 12            HOTEL/MOTEL PARKING LOT        9C40          RD        13
# 13                COMMERCIAL BUILDING        9C30         NaN        14
# 14                          APARTMENT        6B30          DR        15
# 15               ROAD/STREET/SIDEWALK        4F20          DR        16
# 16                                NaN       17E40          DR        17
# 17  STRIP BUSINESS CENTER PARKING LOT         NaN         FWY        18
# 18          DEPARTMENT/DISCOUNT STORE       18F20         AVE        19
# 19              REHABILITATION CENTER       10H40          ST        20
# 20                    RESIDENCE/HOUSE        6B30          DR        21
# 21                    RESIDENCE/HOUSE       13D20          DR        22
# 22                  OTHER PARKING LOT        1A40          RD        23
# 23                           HOSPITAL        6B60          DR        24
# 24                           DRIVEWAY       16E20          DR        25
# 25                          APARTMENT       10H50          ST        26
# 26              APARTMENT PARKING LOT       13D40          RD        27
# 27               RESTAURANT/CAFETERIA        6B50         FWY        28
# 28                    RESIDENCE/HOUSE        2A30         NaN        29
# 29               ROAD/STREET/SIDEWALK        3B50        BLVD        30
# 30                      OTHER/UNKNOWN       19G50          DR        31
# 31                    RESIDENCE/HOUSE        1A10         NaN        32
# 32                           DRIVEWAY       14D20          ST        33
# 33                          APARTMENT        7C10         NaN        34
# 34                    RESIDENCE/HOUSE       15E30          DR        35
# 35                    RESIDENCE/HOUSE       12D50          DR        36
# 36                                NaN       14D30          DR        37
# 37              APARTMENT PARKING LOT       15E30          LN        38
# 38                    RESIDENCE/HOUSE        8C60          ST        39
# 39               RESTAURANT/CAFETERIA        1A30         AVE        40
# 40                                NaN       18F40          RD        41
# 41                    RESIDENCE/HOUSE       14D30         NaN        42
# 42                          APARTMENT        4F30          RD        43
# 43              APARTMENT PARKING LOT        7C20         NaN        44
# 44              APARTMENT PARKING LOT        3B10         NaN        45
# 45                   MALL PARKING LOT       12D70         NaN        46
# 46              APARTMENT PARKING LOT       10H50         NaN        47
# 47                          APARTMENT        3B50         FWY        48
# 5   4.820143e+14       Westside Division    K079            Sharpstown
# 6   4.820133e+14     Clear Lake Division    K117  South Belt / Ellingt
# 7   4.820153e+14          North Division    K032            Oak Forest
# 8   4.820152e+14      Northwest Division    K083    Spring Branch East
# 9   4.820141e+14        Central Division    K023               Midtown
# 10  4.820131e+14       Eastside Division    K011    Lawndale / Wayside
# 11  4.820145e+14       Westside Division    K088                 Alief
# 12  4.820123e+14      Northeast Division    K054            Northshore
# 13  4.820121e+14      Northeast Division    K005  Denver Harbor / Port
# 14  4.820153e+14          North Division    K035                Inwood
# 15  4.820152e+14      Northwest Division    K086   Spring Branch North
# 16  4.820142e+14  South Gessner Division    K073            Brays Oaks
# 17  4.820123e+14                     NaN    K043       Eastex / Jensen
# 18  4.820143e+14        Midwest Division    K081                Uptown
# 19  4.820141e+14  South Central Division    K025              Montrose
# 20  4.820153e+14          North Division    K035                Inwood
# 21  4.820133e+14      Southeast Division    K064  Golfcrest / Bellfort
# 22  4.820141e+14        Central Division    K027  Afton Oaks / River O
# 23  4.820124e+14          North Division    K101           Greenspoint
# 24  4.820133e+14      Southwest Division    K070          Five Corners
# 25  4.820131e+14  South Central Division    K016            Third Ward
# 26  4.820133e+14      Southeast Division    K065                 Hobby
# 27  4.820122e+14          North Division    K101           Greenspoint
# 28  4.820151e+14        Central Division    K030               Heights
# 29  4.820122e+14          North Division    K041  Northside / Northlin
# 30  4.820145e+14       Westside Division    K088                 Alief
# 31  4.820110e+14        Central Division    K001              Downtown
# 32  4.820133e+14      Southeast Division    K069             Sunnyside
# 33  4.820121e+14      Northeast Division    K003            Fifth Ward
# 34           NaN                     NaN     NaN                   NaN
# 35  4.820134e+14     Clear Lake Division    K113            Clear Lake
# 36  4.820133e+14      Southeast Division    K068            South Park
# 37  4.820142e+14      Southwest Division    K071        Willow Meadows
# 38  4.820123e+14      Northeast Division    K046  East Little York / H
# 39  4.820141e+14        Central Division    K026  Upper Kirby / Greenw
# 40  4.820143e+14        Midwest Division    K080              Mid-West
# 41  4.820133e+14      Southeast Division    K068            South Park
# 42  4.820154e+14      Northwest Division    K121            Katy North
# 43  4.820121e+14      Northeast Division    K004      Kashmere Gardens
# 44  4.820153e+14          North Division    K032            Oak Forest
# 45  4.820135e+14     Clear Lake Division    K116   Friendswood: Harris
# 46  4.820131e+14  South Central Division    K016            Third Ward
# 47  4.820122e+14          North Division    K041  Northside / Northlin
# 48  4.820133e+14      Southeast Division    K064  Golfcrest / Bellfort
# 49  4.820131e+14      Southeast Division    K014     OST / South Union
#
#    Geocoded Location_Code Hour
# 0         1           NaN    8
# 1         1           NaN   11
# 2         1           NaN   15
# 3         1           NaN   14
# 4         1           210    7
# 5         1           05Z    3
# 6         1           NaN   19
# 7         1           18O   22
# 8         1           18A   23
# 9         1           05O    7
# 10        1           250   10
# 11        1           190   13
# 12        1           18M   16
# 13        1           05C   15
# 14        1           20A   17
# 15        1           13R   12
# 16        1           NaN   16
# 17        1           18T   11
# 18        1           080   14
# 19        1           09R   13
# 20        1           20R   18
# 21        1           20R   19
# 22        1           18O    5
# 23        1           09H   23
# 24        1           20D    7
# 25        1           20A    0
# 26        1           18A   13
# 27        1           210    0
# 28        1           20R    0
# 29        1           13R   15
# 30        1           250   13
# 31        1           20R    6
# 32        1           20D   22
# 33        1           20A   19
# 34        0           20R   13
# 35        1           20R    0
# 36        1           NaN   20
# 37        1           18A   22
# 38        1           20R   23
# 39        1           210   13
# 40        1           NaN    8
# 41        1           20R   11
# 42        1           20A   15
# 43        1           18A   18
# 44        1           18A    7
# 45        1           18U   18
# 46        1           18A   15
# 47        1           20A   23
# 48        1           120    7
# 49        1           20R    0
#
# [50 rows x 23 columns]

# %%
df.describe()
# Out:
#            RecordID  Num_Offenses            NGC             X             Y  \
# count  1.094207e+06  1.094207e+06  242420.000000  1.080683e+06  1.080683e+06
# mean   5.471040e+05  1.015262e+00       0.012924 -9.387951e+01  2.927203e+01
# std    3.158705e+05  1.613578e-01       0.112946  1.201800e+01  3.748233e+00
# min    1.000000e+00  1.000000e+00       0.000000 -9.578030e+01  0.000000e+00
# 25%    2.735525e+05  1.000000e+00       0.000000 -9.550640e+01  2.968407e+01
# 50%    5.471040e+05  1.000000e+00       0.000000 -9.541192e+01  2.973750e+01
# 75%    8.206555e+05  1.000000e+00       0.000000 -9.533682e+01  2.980469e+01
# max    1.094207e+06  3.300000e+01       1.000000  0.000000e+00  3.009652e+01
#
#             GEOID10       GEOID00      Geocoded          Hour
# count  1.063260e+06  1.063260e+06  1.094207e+06  1.094207e+06
# mean   4.820125e+14  4.820125e+14  9.717174e-01  1.310504e+01
# std    7.909409e+10  7.909512e+10  1.657791e-01  6.425957e+00
# min    4.815767e+14  4.815767e+14  0.000000e+00  0.000000e+00
# 25%    4.820131e+14  4.820131e+14  1.000000e+00  9.000000e+00
# 50%    4.820141e+14  4.820141e+14  1.000000e+00  1.400000e+01
# 75%    4.820145e+14  4.820145e+14  1.000000e+00  1.800000e+01
# max    4.833969e+14  4.833969e+14  1.000000e+00  2.400000e+01

# %%
df.shape
# Out:
# (1094207, 23)

# %%
df.groupby(["Location_Desc", "Street_Type"]).Offense_Type.count()
# Out:
# Location_Desc                              Street_Type
# ADULT BOOK STORE/NEWSSTAND                 AVE              10
#                                            BLVD              4
#                                            DR               31
#                                            FWY             119
#                                            HWY               7
#                                            PKWY              6
#                                            RD               29
#                                            SER               4
#                                            ST                2
# ADULT NOVELTY STORE                        AVE               1
#                                            DR                1
#                                            FWY               2
#                                            RD                5
#                                            ST                2
#                                            WAY               1
# ADULT THEATER/ARCADE                       RD                2
#                                            ST                1
# AIRPORT TERMINAL                           AVE               4
#                                            BLVD            754
#                                            CIR               2
#                                            CT                1
#                                            DR               32
#                                            FWY               3
#                                            LN                5
#                                            PKWY             14
#                                            PL                1
#                                            RD             3086
#                                            SER               5
#                                            ST               36
#                                            TER               1
#                                                           ...
# VEHICLE/AUTO SALES/LEASE/AUTO PARTS STORE  PKWY             45
#                                            PL                2
#                                            RD              887
#                                            SER              14
#                                            ST              557
#                                            TRL              18
#                                            WAY               5
# VIDEO RENTAL & SALES                       AVE               1
#                                            BLVD              8
#                                            DR               24
#                                            FWY              42
#                                            HWY               1
#                                            PKWY              4
#                                            RD               36
#                                            SER               2
#                                            ST               18
# WAREHOUSE                                  AVE              15
#                                            BLVD            117
#                                            CIR               4
#                                            CT                1
#                                            DR              483
#                                            FWY             115
#                                            HWY              22
#                                            LN               59
#                                            PKWY             74
#                                            RD              520
#                                            SER              13
#                                            ST              493
#                                            TRL               3
#                                            WAY               2
# Name: Offense_Type, Length: 1619, dtype: int64
