# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("HPD_Crime_2009_2017_v01.csv")

# %%
df.head(50)
# Out:
#                         Location_Desc Police_Beat Street_Type  RecordID  \
# 0                                 NaN       14D40          RD         1
# 1                                 NaN        7C20         NaN         2
# 2                                 NaN       13D40        PKWY         3
# 3                                 NaN       18F40          RD         4
# 4                RESTAURANT/CAFETERIA       24C60        PKWY         5
# 5       MISC. BUSINESS (NON-SPECIFIC)       18F60        BLVD         6
# 6                                 NaN       12D20         FWY         7
# 7                   OTHER PARKING LOT        3B10         NaN         8
# 8               APARTMENT PARKING LOT        5F10          DR         9
# 9                     OFFICE BUILDING        1A20         NaN        10
# 10                      OTHER/UNKNOWN       11H10         NaN        11
# 11            RENTAL STORAGE FACILITY       19G20          ST        12
# ...

# %%
hr_ot = df.groupby(["Hour", "Offense_Type"])
for group in hr_ot:
    print(group[1].head())
    freq = hr_ot.count()
# Out:
#           Location_Desc Police_Beat Street_Type  RecordID Date_Reported  \
# 568485              NaN        8C50         NaN    568486    08/31/2013
# 732776              NaN       12D10          ST    732777    01/01/2015
# 852636        APARTMENT        8C50         NaN    852637    11/17/2015
# 917690  RESIDENCE/HOUSE       12D20          DR    917691    07/15/2016
#
#        Offense_Type  Block_Range Street_Prefix    Street_Name  Num_Offenses  \
# 568485            1    9200-9299           NaN          NYSSA             1
# 732776            1      800-899           NaN       EASTLAKE             1
# 852636            1    8600-8699           NaN  STERLINGSHIRE             1
# 917690            1  11200-11299           NaN       SAGELAND             1
#
#         ...          X          Y       GEOID10       GEOID00  \
# 568485  ... -95.254073  29.859607  4.820123e+14  4.820123e+14
# 732776  ... -95.233924  29.644339  4.820132e+14  4.820132e+14
# ...

# %%
freq["Num_Offenses"].unstack().plot.bar()

# %%
hr = df.groupby(["Hour"])
for group in hr:
    print(group[1].head())
    total_freq = hr.count()
    ot = df.groupby(["Hour" "Offense_Type"])
    for group in ot
        freq = hr_ot.count()
        prop = hr
# Out:
#            Location_Desc Police_Beat Street_Type  RecordID Date_Reported  \
# 25             APARTMENT       10H50          ST        26    01/01/1966
# 27  RESTAURANT/CAFETERIA        6B50         FWY        28    10/27/1966
# 28       RESIDENCE/HOUSE        2A30         NaN        29    07/22/1969
# 35       RESIDENCE/HOUSE       12D50          DR        36    06/01/1972
# 49       RESIDENCE/HOUSE       14D20         NaN        50    09/12/1978
#
#           Offense_Type  Block_Range Street_Prefix  Street_Name  Num_Offenses  \
# 25                Rape    3300-3399           NaN      ALABAMA             1
# 27               Theft  10300-10399           NaN        NORTH             1
# 28               Theft    1500-1599           NaN    NICHOLSON             1
# 35                Rape  16400-16499           NaN   BROOKVILLA             1
# 49  Aggravated Assault    3500-3599           NaN  MT PLEASANT             1
#
#     ...          X          Y       GEOID10       GEOID00  \
# ...

# %%
# Out:
# <bound method DataFrameGroupBy.count of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x124c88b38>>
